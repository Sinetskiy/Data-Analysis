# %%
from stocker import Stocker

# %%
amazon = Stocker('AMZN')
# Out:
# AMZN Stocker Initialized. Data covers 1997-05-16 00:00:00 to 2018-03-27 00:00:00.

# %%
amazon.plot_stock()
# Out:
# Maximum Adj. Close = 1598.39 on 2018-03-12 00:00:00.
# Minimum Adj. Close = 1.40 on 1997-05-22 00:00:00.
# Current Adj. Close = 1497.05 on 2018-03-27 00:00:00.

# %%
model, model_data = amazon.create_prophet_model(days=90)
# Out:
# Predicted Price on 2018-06-25 00:00:00 = $1885.58

# %%
amazon.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $1055.44.
# Actual price on    2018-03-23 00:00:00 = $1495.56.
#
# Average Absolute Error on Training Data = $16.83.
# Average Absolute Error on Testing  Data = $138.14.
#
# When the model predicted an increase, the price increased 56.41% of the time.
# When the model predicted a  decrease, the price decreased  40.22% of the time.
#
# The actual value was within the 80% confidence interval 55.82% of the time.

# %%
amazon.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $1055.44.
# Actual price on    2018-03-23 00:00:00 = $1495.56.
#
# Average Absolute Error on Training Data = $16.83.
# Average Absolute Error on Testing  Data = $138.14.
#
# When the model predicted an increase, the price increased 56.41% of the time.
# When the model predicted a  decrease, the price decreased  40.22% of the time.
#
# The actual value was within the 80% confidence interval 57.83% of the time.

# %%
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# WARNING:fbprophet:Optimization terminated abnormally. Falling back to Newton.
# Validation Range 2016-01-04 00:00:00 to 2017-01-03 00:00:00.
#
#      cps  train_err  train_range    test_err  test_range
# 0  0.001  44.476286   152.844617  149.378762  152.773329
# 1  0.050  11.258669    35.981081  149.914985  133.070033
# 2  0.100  10.728566    34.679811  150.354635  180.125980
# 3  0.200   9.750940    32.015577  122.978316  338.080511

# %%
# test more changepoint priors on same validation range
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.15, 0.2, 0.25,0.4, 0.5, 0.6])
# Out:
# Validation Range 2016-01-04 00:00:00 to 2017-01-03 00:00:00.
#
#     cps  train_err  train_range    test_err  test_range
# 0  0.15  10.264653    33.381366  142.933425  238.558651
# 1  0.20   9.750940    32.093969  122.978316  313.630087
# 2  0.25   9.447805    31.212119  113.779858  409.964644
# 3  0.40   8.642428    29.008295   78.885355  718.902972
# 4  0.50   8.365811    28.419686   72.357183  821.757133
# 5  0.60   8.292802    28.129881   74.469778  928.968643

# %%
amazon.changepoint_prior_scale = 0.5

# %%
amazon.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $990.46.
# Actual price on    2018-03-23 00:00:00 = $1495.56.
#
# Average Absolute Error on Training Data = $10.80.
# Average Absolute Error on Testing  Data = $184.74.
#
# When the model predicted an increase, the price increased 59.46% of the time.
# When the model predicted a  decrease, the price decreased  45.00% of the time.
#
# The actual value was within the 80% confidence interval 88.76% of the time.

# %%
# Going big 
amazon.evaluate_prediction(nshares=1000)
# Out:
# /Users/ekaterinanikulina/Source/Python/Data-Analysis/stocker/stocker.py:613: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#